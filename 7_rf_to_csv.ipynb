# %%
import ee
import os
import time
import joblib
import geemap
import datetime
import pandas as pd
from geemap import ml
from sklearn import ensemble

# %%
# ee.Authenticate(force=True)

# Initialize Earth Engine
try:
    ee.Initialize(project='ee-aakash312000', opt_url='https://earthengine-highvolume.googleapis.com')
    print('Google Earth Engine initialized successfully!')
except ee.EEException as e:
    print('Google Earth Engine failed to initialize!', e)
    raise
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Google Earth Engine initialized successfully!

# %%
INPUT_FOLDER = "./new_rfr_joblib"
OUTPUT_FOLDER = "./new_rfr_csv"
AEZ = 20
date = "2025-07-03" # datetime.datetime.today().date()
PRED_VARIABLE = "OC"
MODEL_FILE_NAME = f"rfr_model_{date}_AEZ_{AEZ}_{PRED_VARIABLE}.joblib"
rf = joblib.load(os.path.join(INPUT_FOLDER, MODEL_FILE_NAME))
CSV_FILE_NAME = f"rf_trees_t{rf.get_params()['n_estimators']}_d{rf.get_params()['max_depth']}_{date}_AEZ_{AEZ}_{PRED_VARIABLE}.csv"
feature_names = rf.feature_names_in_.tolist()

print(feature_names)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['slope', 'BI', 'SI', 'RI', 'elevation', 'sand05', 'sand515', 'NCI', 'longitude', 'latitude']

# %%
start_time = time.perf_counter()

# convert the estimator into a list of strings
trees = ml.rf_to_strings(rf, feature_names, processes=12, output_mode="REGRESSION")

end_time = time.perf_counter()
elapsed_time = end_time - start_time
a = datetime.timedelta(seconds=elapsed_time)
print("Time taken : " + str(a))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Time taken : 0:00:00.488197

# %%
sizes = [len(trees[i]) for i in range(len(trees))]
print(sizes)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [3730, 3629, 3511, 3424, 3199, 3276, 3224, 3474, 3166, 3625, 3926, 4025, 3109, 3476, 3642, 3672, 3858, 3205, 3312, 3958, 3339, 3017, 3983, 3529, 3721, 3535, 3638, 3373, 3794, 3475, 3629, 3680, 3326, 3323, 3498, 3558, 3752, 3665, 3630, 3621]

# %%
file_path = os.path.join(OUTPUT_FOLDER, CSV_FILE_NAME)
ml.trees_to_csv(trees, file_path)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# df = pd.read_csv(file_path, header=None)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# n = len(df)
# print(f"Number of trees: {n}")

# sizes = [len(df.loc[i].values[0]) for i in range(n)]
# print(f"Tree sizes : {sizes}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
